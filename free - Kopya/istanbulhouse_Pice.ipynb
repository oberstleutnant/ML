# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sbn

from sklearn import preprocessing
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
data = pd.read_csv("price_house.csv")

# %%
data.head()
# Out:
#    İlan_Numarası İlan_Güncelleme_Tarihi Kategorisi  Brüt_Metrekare  \
# 0           2003         02 Şubat 2022    Satılık              190
# 1            166          14 Ocak 2022    Satılık              300
# 2            167          14 Ocak 2022    Satılık              350
# 3            115          06 Ocak 2022    Satılık              450
# 4           2879         08 Şubat 2022    Satılık              160
#
#    Binanın_Yaşı  Binanın_Kat_Sayısı        Kullanım_Durumu Yatırıma_Uygunluk  \
# 0         5-10                   20       Kiracı Oturuyor        Bilinmiyor
# 1  21 Ve Üzeri                    2       Kiracı Oturuyor        Bilinmiyor
# 2  21 Ve Üzeri                    3  Mülk Sahibi Oturuyor        Bilinmiyor
# 3         5-10                    4       Kiracı Oturuyor        Bilinmiyor
# 4  21 Ve Üzeri                    2  Mülk Sahibi Oturuyor        Bilinmiyor
#
#   Eşya_Durumu Banyo_Sayısı  ... Site_İçerisinde Takas  Fiyat_Durumu    Fiyatı  \
# ...

# %%
null = data.isnull().sum()
null
# Out:
# İlan_Numarası             0
# İlan_Güncelleme_Tarihi    0
# Kategorisi                0
# Brüt_Metrekare            0
# Binanın_Yaşı              0
# Binanın_Kat_Sayısı        0
# Kullanım_Durumu           0
# Yatırıma_Uygunluk         0
# Eşya_Durumu               0
# Banyo_Sayısı              0
# İlan_Oluşturma_Tarihi     0
# Türü                      0
# Net_Metrekare             0
# Oda_Sayısı                0
# Bulunduğu_Kat             0
# Isıtma_Tipi               0
# Krediye_Uygunluk          0
# Site_İçerisinde           0
# Takas                     0
# Fiyat_Durumu              0
# Fiyatı                    0
# İl                        0
# İlçe                      0
# Mahalle                   0
# yaka                      0
# Yaşam_endeksi             0
# Nüfus                     0
# dtype: int64

# %%
data.pop("İlan_Numarası")
data.pop("İlan_Güncelleme_Tarihi")
data.pop("İlan_Oluşturma_Tarihi")
data.pop("Takas")
data.pop("Fiyat_Durumu")
data.pop("Kategorisi")
# Out:
# 0       Satılık
# 1       Satılık
# 2       Satılık
# 3       Satılık
# 4       Satılık
#           ...
# 2978    Satılık
# 2979    Satılık
# 2980    Satılık
# 2981    Satılık
# 2982    Satılık
# Name: Kategorisi, Length: 2983, dtype: object

# %%
data.head()
# Out:
#    Brüt_Metrekare  Binanın_Yaşı  Binanın_Kat_Sayısı        Kullanım_Durumu  \
# 0             190         5-10                   20       Kiracı Oturuyor
# 1             300  21 Ve Üzeri                    2       Kiracı Oturuyor
# 2             350  21 Ve Üzeri                    3  Mülk Sahibi Oturuyor
# 3             450         5-10                    4       Kiracı Oturuyor
# 4             160  21 Ve Üzeri                    2  Mülk Sahibi Oturuyor
#
#   Yatırıma_Uygunluk Eşya_Durumu Banyo_Sayısı    Türü  Net_Metrekare  \
# 0       Bilinmiyor          Yok           2   Konut             168
# 1       Bilinmiyor          Yok           3   Konut             270
# 2       Bilinmiyor          Yok           2   Konut             320
# 3       Bilinmiyor          Yok           3   Konut             400
# 4       Bilinmiyor          Yok           1   Konut             140
#
#   Oda_Sayısı  ... Isıtma_Tipi Krediye_Uygunluk Site_İçerisinde    Fiyatı  \
# ...

# %%
corr = data.corr()["Fiyatı"].sort_values()
corr
# Out:
# Nüfus                -0.085103
# Binanın_Kat_Sayısı    0.015430
# Net_Metrekare         0.051061
# Brüt_Metrekare        0.057102
# Yaşam_endeksi         0.090934
# Fiyatı                1.000000
# Name: Fiyatı, dtype: float64

# %%
data2 = data.iloc[:,[0,2,8,14,19,20]]
data3 = data.iloc[:,[1,3,4,5,6,7,9,10,11,12,13,15,16,17,18]]
datab = pd.concat([data2,data3],axis=1)
datab
# Out:
#       Brüt_Metrekare  Binanın_Kat_Sayısı  Net_Metrekare    Fiyatı  \
# 0                190                  20            168  18000000
# 1                300                   2            270   8500000
# 2                350                   3            320  16500000
# 3                450                   4            400  22000000
# 4                160                   2            140   4250000
# ...              ...                 ...            ...       ...
# 2978             550                   4            400   6100000
# 2979             160                   4            145   2050000
# 2980             220                   4            170   7850000
# 2981             950                   3            800   4900000
# 2982             250                   2            235   3700000
#
#       Yaşam_endeksi    Nüfus  Binanın_Yaşı        Kullanım_Durumu  \
# 0             0.911  178.938         5-10        Kiracı Oturuyor
# ...

# %%
data4= pd.DataFrame()
print(data4)
for key in datab.keys():
    if datab[key].dtype == "object":
        new_key = key + "_cat"
        data4[new_key] = datab[key].astype("category").cat.codes
        
    else:
        data4[key] = datab[key]
data4
# Out:
# Empty DataFrame
# Columns: []
# Index: []
#       Brüt_Metrekare  Binanın_Kat_Sayısı  Net_Metrekare    Fiyatı  \
# 0                190                  20            168  18000000
# 1                300                   2            270   8500000
# 2                350                   3            320  16500000
# 3                450                   4            400  22000000
# 4                160                   2            140   4250000
# ...              ...                 ...            ...       ...
# 2978             550                   4            400   6100000
# 2979             160                   4            145   2050000
# 2980             220                   4            170   7850000
# 2981             950                   3            800   4900000
# 2982             250                   2            235   3700000
#
#       Yaşam_endeksi    Nüfus  Binanın_Yaşı_cat  Kullanım_Durumu_cat  \
# ...

# %%
fiyatı = data4[["Fiyatı"]]

# %%
from sklearn.model_selection import train_test_split

x_train, x_test,y_train,y_test = train_test_split(data4.drop(["Fiyatı"],axis=1),fiyatı,test_size=0.33, random_state=0)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x_train,y_train)

tahmin = lr.predict(x_test)
tahmin2 = lr.predict([[85]])
# Out:
# c:\Users\emreu\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\emreu\OneDrive\Masaüstü\VERİ BİLİMİ VE MAKİNE ÖĞRENMESİ\free\istanbulhouse_Pice.ipynb Hücre 12 in <cell line: 6>()
#       <a href='vscode-notebook-cell:/c%3A/Users/emreu/OneDrive/Masa%C3%BCst%C3%BC/VER%C4%B0%20B%C4%B0L%C4%B0M%C4%B0%20VE%20MAK%C4%B0NE%20%C3%96%C4%9ERENMES%C4%B0/free/istanbulhouse_Pice.ipynb#X34sZmlsZQ%3D%3D?line=2'>3</a> lr.fit(x_train,y_train)
#       <a href='vscode-notebook-cell:/c%3A/Users/emreu/OneDrive/Masa%C3%BCst%C3%BC/VER%C4%B0%20B%C4%B0L%C4%B0M%C4%B0%20VE%20MAK%C4%B0NE%20%C3%96%C4%9ERENMES%C4%B0/free/istanbulhouse_Pice.ipynb#X34sZmlsZQ%3D%3D?line=4'>5</a> tahmin = lr.predict(x_test)
# ...
